# %% [markdown]
# <a href="https://colab.research.google.com/github/Khunakorn-Kadkeaw/Design-Thinking-2025/blob/main/Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
from bs4 import BeautifulSoup
import re
import pandas as pd

url = "https://www.jib.co.th/web/product/product_list/2/51"

headers = {
    "User-Agent": "Mozilla/5.0"
}

page = requests.get(url, headers=headers)
soup = BeautifulSoup(page.content, 'html.parser')

# container สินค้าแต่ละชิ้น
items = soup.find_all("div", class_="col-md-3 col-sm-4 col-xs-6 divboxpro")

data = []

for item in items:

    # ===== ดึงชื่อ =====
    name_tag = item.find("span", class_="promo_name")
    if not name_tag:
        continue
    name = name_tag.text.strip()

    # ===== ดึงราคา =====
    price_tag = item.find("p", class_="price_total")
    if not price_tag:
        continue
    price_text = price_tag.text.strip()

    # ล้างให้เหลือเลข
    price_number = re.sub(r"[^\d]", "", price_text)

    # ===== แยก RTX / RX =====
    name_upper = name.upper()

    if re.search(r"\bRTX\b", name_upper):
        series = "RTX"
    elif re.search(r"\bRX\b", name_upper):
        series = "RX"
    else:
        series = "Other"

    # ===== เก็บข้อมูล =====
    data.append({
        "Product": name,
        "Series": series,
        "Price": price_number
    })

# แปลงเป็น DataFrame
df = pd.DataFrame(data)
print(df)

# บันทึกไฟล์
df.to_csv("gpu_prices.csv", index=False, encoding="utf-8-sig")

print("บันทึกไฟล์ recipes_dataset.csv สำเร็จ")
# Out:
#                                               Product Series   Price
# 0   VGA (การ์ดแสดงผล) MSI GEFORCE RTX 5060 8G SHAD...    RTX   11200
# 1   VGA (การ์ดแสดงผล) PNY GEFORCE RTX 5060 DUAL FA...    RTX   10600
# 2   VGA (การ์ดแสดงผล) MSI GEFORCE RTX 5050 8G SHAD...    RTX    9150
# 3   VGA (การ์ดแสดงผล) POWERCOLOR FIGHTER AMD RADEO...     RX    4690
# 4   VGA (การ์ดแสดงผล) ASUS DUAL GEFORCE RTX 3050 O...    RTX    7800
# ..                                                ...    ...     ...
# 95  VGA (การ์ดแสดงผล) LEADTEK NVIDIA RTX PRO 2000 ...    RTX   31900
# 96  VGA (การ์ดแสดงผล) LEADTEK NVIDIA RTX PRO 5000 ...    RTX  185000
# 97  VGA (การ์ดแสดงผล) GALAX GEFORCE RTX 5050 1-CLI...    RTX    9590
# 98  VGA (การ์ดแสดงผล) GIGABYTE GEFORCE RTX 5060 WI...    RTX   11900
# 99               VGA (การ์ดแสดงผล) ASUS PH-GT1030 O2G  Other
#
# [100 rows x 3 columns]
# บันทึกไฟล์ recipes_dataset.csv สำเร็จ

# %%
print(df.head())
print(len(df))
# Out:
#                                              Product Series  Price
# 0  VGA (การ์ดแสดงผล) MSI GEFORCE RTX 5060 8G SHAD...    RTX  11200
# 1  VGA (การ์ดแสดงผล) PNY GEFORCE RTX 5060 DUAL FA...    RTX  10600
# 2  VGA (การ์ดแสดงผล) MSI GEFORCE RTX 5050 8G SHAD...    RTX   9150
# 3  VGA (การ์ดแสดงผล) POWERCOLOR FIGHTER AMD RADEO...     RX   4690
# 4  VGA (การ์ดแสดงผล) ASUS DUAL GEFORCE RTX 3050 O...    RTX   7800
# 100

# %%
import os
print(os.getcwd())
# Out:
# /content

# %%
from google.colab import files
files.download("gpu_prices.csv")
